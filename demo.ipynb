# %%
# !pip install -q google-cloud-speech
# !pip install -q --upgrade google-cloud-translate
# !pip -q install torchtext==0.6.0
# !pip -q install pyvi
# !pip -q install ffmpeg-python
# Out:
#      |████████████████████████████████| 112kB 8.1MB/s
#      |████████████████████████████████| 102kB 7.5MB/s
#      |████████████████████████████████| 51kB 6.1MB/s
#      |████████████████████████████████| 512kB 12.3MB/s
#      |████████████████████████████████| 645kB 17.3MB/s
#      |████████████████████████████████| 102kB 6.2MB/s
#      |████████████████████████████████| 71kB 5.6MB/s
#      |████████████████████████████████| 1.2MB 12.1MB/s
#      |████████████████████████████████| 8.5MB 4.0MB/s
#      |████████████████████████████████| 747kB 49.2MB/s

# %%
# !pip install -q flask-ngrok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/NLP_project/'
# Out:
# /content/drive/.shortcut-targets-by-id/1kWFkPboOT_MgvjCmTkgRnw2lbnQb8HPw/NLP_project

# %%
# !pip -q install './model/vi_spacy_model-0.2.1.tar.gz'
# !python -m spacy link vi_spacy_model vi_spacy_model
# Out:
#   Building wheel for vi-spacy-model (setup.py) ... done
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/vi_spacy_model -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/vi_spacy_model
# You can now load the model via spacy.load('vi_spacy_model')

# %%
# !python main.py
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#  * Serving Flask app "main" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://385dc49dca0f.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [01/Mar/2021 02:07:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:07:18] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [01/Mar/2021 02:07:20] "GET /text HTTP/1.1" 200 -
# /content/drive/.shortcut-targets-by-id/1kWFkPboOT_MgvjCmTkgRnw2lbnQb8HPw/NLP_project/src/transformer.py:486: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   ones = (outputs==eos_tok).nonzero() # Occurrences of end symbols for all input sentences.
# 127.0.0.1 - - [01/Mar/2021 02:08:28] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:10:28] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:10:44] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:10:52] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:12:07] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:12:54] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:18:54] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:25:51] "GET /audio HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:25:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:25:58] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:41:45] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:42:07] "GET /audio HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:42:08] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:44:04] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:45:05] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:46:08] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:46:24] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:46:59] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:47:37] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:50:19] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:50:34] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:50:42] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:51:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:52:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:52:11] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [01/Mar/2021 02:52:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:52:43] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [01/Mar/2021 02:55:47] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:55:51] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:56:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:56:21] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:56:32] "GET /record HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:56:48] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:57:05] "GET /audio HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:57:22] "POST /audio HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:58:30] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:58:32] "GET /audio HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:58:38] "GET /audio HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 02:58:43] "GET /audio HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 03:16:13] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 03:16:22] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 03:16:45] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 03:32:40] "GET /audio HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 03:32:45] "GET /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 03:33:25] "POST /text HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Mar/2021 03:33:55] "POST /text HTTP/1.1" 200 -
